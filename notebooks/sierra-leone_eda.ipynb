# %%
from sklearn.preprocessing import StandardScaler

# Example: Scaling the features
scaler = StandardScaler()
df[['GHI', 'DNI', 'DHI', 'Tamb']] = scaler.fit_transform(df[['GHI', 'DNI', 'DHI', 'Tamb']])

# Example: Feature creation (e.g., create new features based on existing ones)
df['GHI_DHI_ratio'] = df['GHI'] / (df['DHI'] + 1e-5)  # Prevent division by zero

# Preview the changes
print(df.head())
